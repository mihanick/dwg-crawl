# %% [markdown]
# # Query and save test dataset

# %%
# https://stackoverflow.com/questions/16249736/how-to-import-data-from-mongodb-to-pandas
import pymongo
import pandas as pd
import numpy as np
from pymongo import MongoClient
from processing import *

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
client = MongoClient('mongodb://192.168.0.104:27017/')
db = client.geometry

# %%
fileids  = db.files.find({'Valid':True}).distinct('FileId')
print(len(fileids))

query = {
    'ClassName':
    {
        '$in':[
            'AcDbLine',
            'AcDbText',
            'AcDbRotatedDimension'
        ]
    },
    'FileId':{
        '$in':fileids
    }
}

data = pd.DataFrame(list(db.objects.find(query)))
# Out:
# 322

# %%
cols_to_expand = ['XLine1Point', 'XLine2Point','StartPoint','EndPoint','Position']
data = expand_columns(data, cols_to_expand)

# %%
len(data)
# Out:
# 917991

# %%
test_data = data.sample(frac = 0.01)
test_data.groupby(['FileId', 'ClassName']).count()
# Out:
#                                                            _id  Color  Layer  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                9      9      9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                6      6      6
#                                      AcDbText                2      2      2
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                2      2      2
#                                      AcDbText                1      1      1
# ...                                                        ...    ...    ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension    1      1      1
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                5      5      5
#                                      AcDbText                1      1      1
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine               13     13     13
#                                      AcDbText                5      5      5
#
#                                                            LineWeight  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                       9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                       6
#                                      AcDbText                       2
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                       2
#                                      AcDbText                       1
# ...                                                               ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension           1
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                       5
#                                      AcDbText                       1
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                      13
#                                      AcDbText                       5
#
#                                                            Linetype  ObjectId  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                     9         9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                     6         6
#                                      AcDbText                     2         2
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                     2         2
#                                      AcDbText                     1         1
# ...                                                             ...       ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension         1         1
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                     5         5
#                                      AcDbText                     1         1
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                    13        13
#                                      AcDbText                     5         5
#
#                                                            EndPoint  Length  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                     9       9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                     6       6
#                                      AcDbText                     0       0
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                     2       2
#                                      AcDbText                     0       0
# ...                                                             ...     ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension         0       0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                     5       5
#                                      AcDbText                     0       0
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                    13      13
#                                      AcDbText                     0       0
#
#                                                            StartPoint  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                       9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                       6
#                                      AcDbText                       0
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                       2
#                                      AcDbText                       0
# ...                                                               ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension           0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                       5
#                                      AcDbText                       0
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                      13
#                                      AcDbText                       0
#
#                                                            DimLinePoint  ...  \
# FileId                               ClassName                           ...
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                         0  ...
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                         0  ...
#                                      AcDbText                         0  ...
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                         0  ...
#                                      AcDbText                         0  ...
# ...                                                                 ...  ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension             1  ...
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                         0  ...
#                                      AcDbText                         0  ...
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                         0  ...
#                                      AcDbText                         0  ...
#
#                                                            StartPoint.Y  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                         9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                         6
#                                      AcDbText                         0
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                         2
#                                      AcDbText                         0
# ...                                                                 ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension             0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                         5
#                                      AcDbText                         0
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                        13
#                                      AcDbText                         0
#
#                                                            StartPoint.Z  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                         9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                         6
#                                      AcDbText                         0
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                         2
#                                      AcDbText                         0
# ...                                                                 ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension             0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                         5
#                                      AcDbText                         0
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                        13
#                                      AcDbText                         0
#
#                                                            EndPoint.ClassName  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                               9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                               6
#                                      AcDbText                               0
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                               2
#                                      AcDbText                               0
# ...                                                                       ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension                   0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                               5
#                                      AcDbText                               0
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                              13
#                                      AcDbText                               0
#
#                                                            EndPoint.X  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                       9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                       6
#                                      AcDbText                       0
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                       2
#                                      AcDbText                       0
# ...                                                               ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension           0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                       5
#                                      AcDbText                       0
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                      13
#                                      AcDbText                       0
#
#                                                            EndPoint.Y  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                       9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                       6
#                                      AcDbText                       0
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                       2
#                                      AcDbText                       0
# ...                                                               ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension           0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                       5
#                                      AcDbText                       0
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                      13
#                                      AcDbText                       0
#
#                                                            EndPoint.Z  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                       9
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                       6
#                                      AcDbText                       0
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                       2
#                                      AcDbText                       0
# ...                                                               ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension           0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                       5
#                                      AcDbText                       0
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                      13
#                                      AcDbText                       0
#
#                                                            Position.ClassName  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                               0
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                               0
#                                      AcDbText                               2
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                               0
#                                      AcDbText                               1
# ...                                                                       ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension                   0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                               0
#                                      AcDbText                               1
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                               0
#                                      AcDbText                               5
#
#                                                            Position.X  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                       0
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                       0
#                                      AcDbText                       2
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                       0
#                                      AcDbText                       1
# ...                                                               ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension           0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                       0
#                                      AcDbText                       1
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                       0
#                                      AcDbText                       5
#
#                                                            Position.Y  \
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                       0
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                       0
#                                      AcDbText                       2
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                       0
#                                      AcDbText                       1
# ...                                                               ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension           0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                       0
#                                      AcDbText                       1
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                       0
#                                      AcDbText                       5
#
#                                                            Position.Z
# FileId                               ClassName
# 006cb2dd-6f18-4203-8b70-fc865c08105a AcDbLine                       0
# 006f290c-7280-491b-b7d7-971ed82de1a5 AcDbLine                       0
#                                      AcDbText                       2
# 0100c16b-c7c9-4265-92b9-950bf5d2c9ec AcDbLine                       0
#                                      AcDbText                       1
# ...                                                               ...
# 85f78f77-85c3-484a-964e-7769ea5804ae AcDbRotatedDimension           0
# 864ce51e-79b8-4c65-99ca-dfdf738dfff2 AcDbLine                       0
#                                      AcDbText                       1
# 87780373-9950-40b6-871c-6346f04b90af AcDbLine                       0
#                                      AcDbText                       5
#
# [613 rows x 37 columns]

# %%
test_data.columns
# Out:
# Index(['_id', 'Color', 'Layer', 'LineWeight', 'Linetype', 'ObjectId',
#        'ClassName', 'EndPoint', 'Length', 'StartPoint', 'FileId',
#        'DimLinePoint', 'DimensionStyleName', 'DimensionText', 'TextPosition',
#        'XLine1Point', 'XLine2Point', 'Position', 'TextString',
#        'XLine1Point.ClassName', 'XLine1Point.X', 'XLine1Point.Y',
#        'XLine1Point.Z', 'XLine2Point.ClassName', 'XLine2Point.X',
#        'XLine2Point.Y', 'XLine2Point.Z', 'StartPoint.ClassName',
#        'StartPoint.X', 'StartPoint.Y', 'StartPoint.Z', 'EndPoint.ClassName',
#        'EndPoint.X', 'EndPoint.Y', 'EndPoint.Z', 'Position.ClassName',
#        'Position.X', 'Position.Y', 'Position.Z'],
#       dtype='object')

# %%
test_columns = [
    'ClassName', 'FileId',
    'XLine1Point.X', 'XLine1Point.Y','XLine1Point.Z', 
    'XLine2Point.X', 'XLine2Point.Y', 'XLine2Point.Z',
                
   'StartPoint.X', 'StartPoint.Y', 'StartPoint.Z',

   'EndPoint.X', 'EndPoint.Y', 'EndPoint.Z',
   'Position.X', 'Position.Y', 'Position.Z']

# %%
test_data['ClassName'] = test_data['ClassName'].astype('category')
test_data['FileId'] = test_data['FileId'].astype('category')
test_data[test_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9180 entries, 867872 to 6212
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ClassName      9180 non-null   category
#  1   FileId         9180 non-null   category
#  2   XLine1Point.X  466 non-null    float64
#  3   XLine1Point.Y  466 non-null    float64
#  4   XLine1Point.Z  466 non-null    float64
#  5   XLine2Point.X  466 non-null    float64
#  6   XLine2Point.Y  466 non-null    float64
#  7   XLine2Point.Z  466 non-null    float64
#  8   StartPoint.X   7748 non-null   float64
#  9   StartPoint.Y   7748 non-null   float64
#  10  StartPoint.Z   7748 non-null   float64
#  11  EndPoint.X     7748 non-null   float64
#  12  EndPoint.Y     7748 non-null   float64
#  13  EndPoint.Z     7748 non-null   float64
#  14  Position.X     966 non-null    float64
#  15  Position.Y     966 non-null    float64
#  16  Position.Z     966 non-null    float64
# dtypes: category(2), float64(15)
# memory usage: 1.2 MB

# %%
sv = test_data[test_columns]
sv.to_pickle('test_dataset.pickle')
